# %% [markdown]
# # Lesson 1.2: Python Basics
# ## Topics Covered:
# - Syntax and Semantics
# - Variables and Data Types
# - Basic Operators (Arithmetic, Comparison, Logical)

# %% [markdown]
# ## 1. Syntax and Semantics
#
# **Question 1:** Write a Python program to print "Hello, World!".

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# **Question 2:** Write a Python program that takes a user input and prints it.

# %%
name = input("What's your name?\n")

print(f"Nice to meet you, {name}!")
# Out:
# Nice to meet you, José!

# %% [markdown]
# **Question 3:** Write a Python program to check if a number is positive, negative, or zero.

# %%
number = input("What's the number?\n")

if int(number) > 0:
    print(f"The number {number} is positive.")
elif int(number) < 0:
    print(f"The number {number} is negative.")
elif int(number) == 0:
    print(f"The number is {number}.")
# Out:
# The number is 0.

# %% [markdown]
# **Question 4:** Write a Python program to find the largest of three numbers.

# %%
number1 = input("Enter the first number:\n")
number2 = input("Enter the second number:\n")
number3 = input("Enter the third number:\n")

if int(number1) > int(number2) and int(number1) > int(number3):
    print(f"The largest number is {number1}.")
elif int(number2) > int(number1) and int(number2) > int(number3):
    print(f"The largest number is {number2}.")
else:
    print(f"The largest number is {number3}.")
# Out:
# The largest number is 9.

# %% [markdown]
# **Question 5:** Write a Python program to calculate the factorial of a number.

# %%
import math as m

'''
number = input("Write the number:\n")

def factorial(number):
    if number < 0:
        raise ValueError("The number needs to be a positive integer!")
    else:
        result = 1
        for n in range(1, number + 1):
            result *= n
        return result 
        
print(f"The factorial of {number} is {factorial(int(number))}.")
'''

number = input("Write the number:\n")

def factorial(number):
    return m.factorial(int(number))
        
print(f"The factorial of {number} is {factorial(number)}.")
# Out:
# The factorial of 4 is 24.

# %% [markdown]
# ## 2. Variables and Data Types
#
# **Question 6:** Create variables of different data types: integer, float, string, and boolean. Print their values and types.

# %%
number = 2
decimal_number = 34.45
text = "Hello World"
option = False

print(f"Type: {type(number)}\nValue: {number}\n")
print(f"Type: {type(decimal_number)}\nValue: {decimal_number}\n")
print(f"Type: {type(text)}\nValue: {text}\n")
print(f"Type: {type(option)}\nValue: {option}")
# Out:
# Type: <class 'int'>
# Value: 2
#
# Type: <class 'float'>
# Value: 34.45
#
# Type: <class 'str'>
# Value: Hello World
#
# Type: <class 'bool'>
# Value: False

# %% [markdown]
# **Question 7:** Write a Python program to swap the values of two variables.

# %%
number1 = input("Write the first number:\n")
number2 = input("Write the second number:\n")

def swap_numbers(num1, num2):
    aux = num1
    num1 = num2
    num2 = aux
    return num1, num2

print(f"---Numbers before swapping---\nFirst number -> {number1}\nSecond number -> {number2}\n")
num1, num2 = swap_numbers(number1, number2)
print(f"---Numbers after swapping---\nFirst number -> {num1}\nSecond number -> {num2}\n")
# Out:
# ---Numbers before swapping---
# First number -> 4
# Second number -> 1
#
# ---Numbers after swapping---
# First number -> 1
# Second number -> 4

# %% [markdown]
# **Question 8:** Write a Python program to convert Celsius to Fahrenheit.

# %%
# °F = °C * 1.8 + 32
celsius = input("Write the temperature in Celsius:\n")

def cel_to_fahr(c):
    return int(c) * 1.8 + 32

print(f"{celsius} ºC is {cel_to_fahr(45)} °F.")
# Out:
# 45 ºC is 113.0 °F.

# %% [markdown]
# **Question 9:** Write a Python program to concatenate two strings.

# %%
string1 = input("Write the first string:\n")
string2 = input("Write the second string:\n")

print(f"{string1}{string2}")
# Out:
# HelloWorld

# %% [markdown]
# **Question 10:** Write a Python program to check if a variable is of a specific data type.

# %%
var = "False"

if type(var) == bool:
    print(f"The variable with value '{var}' is a Boolean.")
elif type(var) == int:
    print(f"The variable with value '{var}' is an Integer.")
elif type(var) == float:
    print(f"The variable with value '{var}' is a Float.")
elif type(var) == str:
    print(f"The variable with value '{var}' is a String.")
# Out:
# The variable with value 'False' is a String.

# %% [markdown]
# ## 3. Basic Operators (Arithmetic, Comparison, Logical)
#
# **Question 11:** Write a Python program to perform arithmetic operations: addition, subtraction, multiplication, and division.

# %%
print("---Calculator---\n")
print("[A] Addition")
print("[S] Subtraction")
print("[M] Multiplication")
print("[D] Division\n")
option = input("Choose the operation (letter only):\n")


def addition(*args):
    numbers = args[0].split(", ")
    
    int_list = [int(n) for n in numbers]
        
    return sum(int_list)


def subtraction(*args):
    numbers = args[0].split(", ")
    
    int_list = [int(n) for n in numbers]
    
    result = int_list[0]
    
    for n in int_list:
        if n == int_list[0]:
            continue
        
        result -= n
    
    return result


def multiplication(*args):
    numbers = args[0].split(", ")
    
    int_list = [int(n) for n in numbers]
    
    result = int_list[0]
    
    for n in int_list:
        if n == int_list[0]:
            continue
        
        result *= n
    
    return result


def division(*args):
    numbers = args[0].split(", ")
    
    int_list = [int(n) for n in numbers]
    
    result = int_list[0]
    
    for n in int_list:
        if n == int_list[0]:
            continue
        
        result /= n
    
    return result    


if option == "A" or option == "a":
    numbers = input("Write the numbers to add separated by commas:\n")
    print(f"Result: {addition(numbers)}")
elif option == "S" or option == "s":
    numbers = input("Write the numbers to subtract separated by commas:\n")
    print(f"Result: {subtraction(numbers)}")
elif option == "M" or option == "m":
    numbers = input("Write the numbers to multiply separated by commas:\n")
    print(f"Result: {multiplication(numbers)}")
elif option == "D" or option == "d":
    numbers = input("Write the numbers to divide separated by commas:\n")
    print(f"Result: {division(numbers)}")
# Out:
# ---Calculator---
#
# [A] Addition
# [S] Subtraction
# [M] Multiplication
# [D] Division
#
# Result: 0.024594907407407406

# %% [markdown]
# **Question 12:** Write a Python program to demonstrate comparison operators: equal to, not equal to, greater than, less than.

# %%
number1 = input("Write the first number:\n")
number2 = input("Write the second number:\n")

if number1 == number2:
    print(f"The numbers {number1} and {number2} are equal.") 
elif number1 != number2:
    print(f"The numbers {number1} and {number2} are not equal.")
    
    if number1 > number2:
        print(f"The number {number1} is greater than number {number2}.")
    else:
        print(f"The number {number1} is less than number {number2}.")
# Out:
# The numbers 0 and 7 are not equal.
# The number 0 is less than number 7.

# %% [markdown]
# **Question 13:** Write a Python program to demonstrate logical operators: and, or, not.

# %%
num1 = 0
num2 = 0
st = True

print(num1 and num2)
print(num1 or num2)
print(not st)
# Out:
# 0
# 0
# False

# %% [markdown]
# **Question 14:** Write a Python program to calculate the square of a number.

# %%
import math as m

n = input("Write a number to calculate its square:\n")

print(f"The square of {n} is {int(m.pow(int(n), 2))}.")
# Out:
# The square of 3 is 9.

# %% [markdown]
# **Question 15:** Write a Python program to check if a number is even or odd.

# %%
n = input("Write a number:\n")

if int(n) % 2 == 0:
    print(f"The number {n} is even.")
else:
    print(f"The number {n} is odd.")
# Out:
# The number 1 is odd.

# %% [markdown]
# **Question 16:** Write a Python program to find the sum of the first n natural numbers.

# %%
# Sn = (n * (n + 1)) / 2

num = input("What is the number?:\n")

def sum_first_natural(number):
    return int((int(number) * (int(number) + 1)) / 2)

print(f"The sum of the first natural numbers is {sum_first_natural(num)}.")
# Out:
# The sum of the first natural numbers is 6.

# %% [markdown]
# **Question 17:** Write a Python program to check if a year is a leap year.

# %%
year = input("What is the year?:\n")

if (int(year) % 4 == 0 and int(year) % 100 != 0) or (int(year) % 400 == 0):
    print(f"The year {year} is a leap year.")
else:
    print(f"The year {year} isn't a leap year.")
# Out:
# The year 2015 isn't a leap year.

# %% [markdown]
# **Question 18:** Write a Python program to reverse a string.

# %%
text = input("Write something:\n")

def reverse_string(s):
    return s[::-1]

print(reverse_string(text))
# Out:
# dlroW olleH

# %% [markdown]
# **Question 19:** Write a Python program to check if a string is a palindrome.

# %%
text = input("Write something:\n")

def is_palindrome(s):
    if s == s[::-1]:
        print(f"'{s}' is a palindrome.")
    else:
        print(f"'{s}' isn't a palindrome.")

is_palindrome(text)
# Out:
# 'fuck' isn't a palindrome.

# %% [markdown]
# **Question 20:** Write a Python program to sort a list of numbers in ascending order.

# %%
numbers = input("Write the numbers to sort:\n")

def sort_numbers_asc(*args):
    numbers = args[0].split(", ")
    
    int_list = [int(n) for n in numbers]
    
    return sorted(int_list)

print(f"Sorted numbers in ascending order: {sort_numbers_asc(numbers)}")
# Out:
# Sorted numbers in ascending order: [0, 1, 4, 5]
